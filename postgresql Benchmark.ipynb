# %% [markdown]
# # set up to load postgres with "n" years of mortgage data
#
# postgresql is very fussy during bulk loads. in this instance, the bulk load would only work if all columns were defined as varchar. When numerics were used, this process failed any time an empty field was encountered for a numeric field.
#
# Resolving this required creating additional functions to

# %%
# standard imports
# import required services
import datetime
import json
import platform
import time
import warnings
from pathlib import Path
import os
import glob
import shutil
import inspect

import click
import duckdb
import ibis
import psutil
from jinja2 import Template
from memory_profiler import memory_usage

import psycopg2

from getpass import getpass

# %%
def setGlobals(data="data", perf="perf", acq="acq", threads=6, years=2, mode="sql", db="mortgage.db"):
    env = {}
    # print(f"{inspect.stack()[0][3]}  entered")
    # specify the name of the 'data' sub-folder
    env["data_folder"] = data
    #enable this to run on Linux, OSX, Windows
    env["path_separator"] = os.path.sep
    # define path information for source data sets. 
    env["base_path"] = os.getcwd()
    #env["data_path"] = env["base_path"] + env["path_separator"] + env["data_folder"]
    env["pg_uid"] = os.getlogin()
    env["data_path"] = env["data_folder"]
    env["perf_path"] = env["data_path"] + env["path_separator"] + perf
    env["acq_path"] = env["data_path"] + env["path_separator"] + acq
    env["full_perf"] = env["base_path"] + env["path_separator"] + env["perf_path"]
    env["full_acq"] = env["base_path"] + env["path_separator"] + env["acq_path"]
    env["threads"] = threads
    env["years"] = years
    env["mode"] = mode
    env["db"] = db
    env["db_base"] = "postgres"
    env["create_SQL"] = "postgresql_create.sql"
    env["acq_load_template"] = "postgresql_acq_load_template.sql"
    env["perf_load_template"] = "postgresql_perf_load_template.sql"
    env["summary_sql"] = "postgresql_summary.sql"
    env["postgres"] = {"user": env["pg_uid"], }
    
    # set up the select criteria for finding the correct performance and acquisition files
    if years > 10:
        #first 10 years
        year_list = list(range(0,10))
        env["perf_regex"] = "'Performance_200{0}*.txt*'".format(year_list)
        env["acq_regex"] = "'Acquisition_200{0}*.txt*'".format(year_list)
        #everything else
        year_list = list(range(0,env["years"]-10))
        env["perf_regex_2"] = "'Performance_201{0}*.txt*'".format(year_list)
        env["acq_regex_2"] = "'Acquisition_201{0}*.txt*'".format(year_list)
    else:
        env["acq_regex_2"] = None
        env["perf_regex_2"] = None
        year_list = list(range(0,env["years"]))
        env["perf_regex"] = "'Performance_200{0}*.txt*'".format(year_list)
        env["acq_regex"] = "'Acquisition_200{0}*.txt*'".format(year_list)
    env["platform"] = platform_info()
    
    return env

# %%
def platform_info():
    print(f"{inspect.stack()[0][3]}  entered")
    return {
        "machine": platform.machine(),
        "version": platform.version(),
        "platform": platform.platform(),
        "system": platform.system(),
        "cpu_count": psutil.cpu_count(),
        "memory": psutil.virtual_memory().total,
        "processor": platform.processor(),
    }

# %%
def getMortgageFiles(env_in):
    env = env_in
    # print(f"{inspect.stack()[0][3]}  entered")
    # get a list of the files to be copied

    os.chdir(env["full_perf"])
    perf_list = eval("glob.glob({0})".format(env["perf_regex"]))
    if env["perf_regex_2"] != None:
        t_list = eval("glob.glob({0})".format(env["perf_regex_2"]))
        perf_list = perf_list + t_list

    os.chdir(env["full_acq"])
    t_str = "glob.glob({0})".format(env["acq_regex"])
    acq_list = eval(t_str)
    if env["acq_regex_2"] != None:
        t_list = eval("glob.glob({0})".format(env["acq_regex_2"]))
        acq_list = acq_list + t_list

    env["perf_list"] = perf_list
    perf_files_list = map(lambda x : env["full_perf"] + env["path_separator"] + x, env["perf_list"])
    env["perf_files"] = list(perf_files_list)
    
    env["acq_list"] = acq_list
    acq_files_list = map(lambda x : env["full_acq"] + env["path_separator"] + x, env["acq_list"])
    env['acq_files'] = list(acq_files_list)

    # reset back to the root folder for this repo. 
    os.chdir(env["base_path"])
    
    return env

# %%
def createLocalDB(env_in):
    env = env_in
    # run sql to create "mortgage_analysis" collection and the two tables (perf and acq)
    
    # password for mysql dev environment (yes, probably a better way to do this ...)
    #pw = getpass(prompt='Please enter your MySQL Password: ', stream=None) 
    #env['pw'] = pw
    connection_request = f"dbname={env['db_base']} user={env['postgres']['user']}"
    # print({connection_request})
    try:
        conn = psycopg2.connect(connection_request)
        if conn.status == psycopg2.extensions.STATUS_READY:
            print(f"Connected to {env['db_base']} database")
    except psycopg2.OperationalError as e:
            print(e)
    # Open a cursor to perform database operations
    conn.set_session(autocommit=True)
    cursor = conn.cursor()
    create_file = open(env["base_path"]+env["path_separator"]+env["create_SQL"], "r")
    create_sql = create_file.readlines()
    
    for line in create_sql:
        # print(f"Executing: {line}")
        try:
            cursor.execute(line)
        except psycopg2.OperationalError as e:
            print(f"{line} \n{e}")
    conn.close()
    # print(f"{env['db_base']} tables created")
    return env

# %%
def loadTable(env_in, template, file_list):
    env = env_in
    from mysql.connector import Error
    _file = open(env["base_path"]+env["path_separator"]+template, "r")
    _template = _file.readlines()
    connection_request = f"dbname={env['db_base']} user={env['postgres']['user']}"
    # print({connection_request})
    try:
        conn = psycopg2.connect(connection_request)
        if conn.status == psycopg2.extensions.STATUS_READY:
            print(f"Connected to {env['db_base']} database")
        else:
            print(f"connection error: {conn.status}")
    except psycopg2.OperationalError as e:
        print(e)
    cursor = conn.cursor()
    print("starting table load")
    t0 = time.time()
    res = []
    for _file in file_list:
        print(f"{_file}")
        _sql = _template[0].format(_file)
        try:
            res = cursor.execute(_sql)
        except psycopg2.OperationalError as e:
            print(f"{_sql} \n{e}")

    t1 = time.time()
    print(f"Years: {env['years']} Table load time: {t1-t0}") 
    conn.commit()
    conn.close()
    return env

# %%
def runSummarySQL(env_in):
    env = env_in
    _sql = open(env["base_path"]+env["path_separator"]+env["summary_sql"], "r").read()
    _sql_list = _sql.split("\n")
    _sql_list2 = []
    for each in _sql_list: 
        _sql_list2.append(each.strip())
                          
    summary_sql = " ".join(_sql_list2)
    connection_request = f"dbname={env['db_base']} user={env['postgres']['user']}"
    # print({connection_request})
    try:
        conn = psycopg2.connect(connection_request)
        print(f"conn: {conn}")
        if conn.status == psycopg2.extensions.STATUS_READY:
            print(f"Connected to {env['db_base']} database")
    except psycopg2.OperationalError as e:
        print(e)
    cursor = conn.cursor()
    #cursor.execute("USE mortgage_analysis;")
    print("starting summary sql run")
    t0 = time.time()
    # cursor.execute("USE mortgage_analysis;")
    try:
        res = cursor.execute(summary_sql)
        rows = cursor.fetchall()
    except psycopg2.OperationalError as e:
        print(f"summary sql error: \n{e}")
    t1 = time.time()
    conn.close()
    print(f"Years: {env['years']} rows: {len(rows)} summary sql execution time: {t1-t0}")
    print(rows)
    return env

# %%
def countRows(query):
    connection_request = f"dbname={env['db_base']} user={env['postgres']['user']}"
    print({connection_request})
    try:
        conn = psycopg2.connect(connection_request)
        if conn.status == psycopg2.extensions.STATUS_READY:
            print(f"Connected to {env['db_base']} database")
    except psycopg2.OperationalError as e:
        print(e)
    cursor = conn.cursor()
    #cursor.execute("USE mortgage_analysis;")
    # print("starting countRows sql run")
    t0 = time.time()
    #cursor.execute("USE mortgage_analysis;")
    res = []
    try:
        res = cursor.execute(query)
        row_count = cursor.fetchall()
    except psycopg2.OperationalError as e:
        print(f"summary sql error: \n{e}")
    t1 = time.time()
    print(f"Years: {env['years']} count sql execution time: {t1-t0} rows: {row_count[0][0]}")
    conn.close()

# %%
def fix_empty_int(env_in, _table, _field_list):
    emv = env_in
    connection_request = f"dbname={env['db_base']} user={env['postgres']['user']}"
    # print({connection_request})
    try:
        conn = psycopg2.connect(connection_request)
        if conn.status == psycopg2.extensions.STATUS_READY:
            print(f"Connected to {env['db_base']} database")
    except psycopg2.OperationalError as e:
        print(e)
    conn.set_session(autocommit=True)
    cursor = conn.cursor()
    for field in _field_list:
        _sql_string = f"UPDATE {_table} SET {field[0]} = cast(nullif({field[0]}, '') AS {field[1]});"
        _alter_string = (f"ALTER TABLE {_table} ALTER COLUMN {field[0]} TYPE {field[1]} USING {field[0]}::{field[1]};")
        print(f"Attempting: {_sql_string}")
        t0 = time.time()
        res = []
        try:
            res = cursor.execute(_sql_string)
            res = cursor.execute(_alter_string)
        except psycopg2.OperationalError as e:
            print(f"fix_empty_int error: \n{e}")
        t1 = time.time()
        print(f"Years: {env['years']} fix_empty_int execution time: {t1-t0} field: {field[0]}")

    schema_request = (f"SELECT table_name, column_name, data_type FROM information_schema.columns WHERE table_name = '{_table}';")
    try:
        res = cursor.execute(schema_request)
        rows = cursor.fetchall()
    except psycopg2.OperationalError as e:
        print(f"fix_empty_int error: \n{e}")
    #for each in rows:
    #    print(f"{each[0]}\t{each[1]}\t{each[2]}")
    conn.close()
    return env

# %%
env = setGlobals(data="data/text", years=2)
env = getMortgageFiles(env)

env = createLocalDB(env)

env = loadTable(env, env["acq_load_template"], env["acq_files"])
# fix empty string issue with acq
env = fix_empty_int(env, "acq", [("borrower_credit_score", "INTEGER")])
env = loadTable(env, env["perf_load_template"], env["perf_files"])
# fix empty string issue with perf
env = fix_empty_int(env, "perf", [("current_loan_delinquency_status", "INTEGER"), ("current_actual_upb", "DECIMAL"), ("loan_age", "DECIMAL")])

p_count = "SELECT count(*) FROM perf"
a_count = "SELECT count(*) FROM acq"

countRows(a_count)
countRows(p_count)

env = runSummarySQL(env)
# Out:
# platform_info  entered
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# Executing: DROP DATABASE IF EXISTS mortgage_analysis;
#
# Executing: CREATE DATABASE mortgage_analysis;
#
# Executing: DROP TABLE IF EXISTS acq;
#
# Executing: CREATE TABLE acq (id SERIAL PRIMARY KEY, loan_id VARCHAR(255), orig_channel VARCHAR(255), seller_name VARCHAR(255), orig_interest_rate VARCHAR(255), orig_upb VARCHAR(255), orig_loan_term VARCHAR(255), orig_date VARCHAR(255), first_pay_date VARCHAR(255), orig_ltv VARCHAR(255), orig_cltv VARCHAR(255), num_borrowers VARCHAR(255), dti VARCHAR(255), borrower_credit_score VARCHAR(255), first_home_buyer VARCHAR(255), loan_purpose VARCHAR(255), property_type VARCHAR(255), num_units VARCHAR(255), occupancy_status VARCHAR(255), property_state VARCHAR(255), zip VARCHAR(255), mortgage_insurance_percent VARCHAR(255), product_type VARCHAR(255), coborrow_credit_score VARCHAR(255), mortgage_insurance_type VARCHAR(255), relocation_mortgage_indicator VARCHAR(255), dummy VARCHAR(255));
#
# Executing: DROP TABLE IF EXISTS perf;
#
# Executing: CREATE TABLE perf (id SERIAL PRIMARY KEY, loan_id VARCHAR(255), monthly_reporting_period VARCHAR(255), servicer VARCHAR(255), interest_rate VARCHAR(255), current_actual_upb VARCHAR(255), loan_age VARCHAR(255), remaining_months_to_legal_maturity VARCHAR(255), adj_remaining_months_to_maturity VARCHAR(255), maturity_date VARCHAR(255), msa VARCHAR(255), current_loan_delinquency_status VARCHAR(255), mod_flag VARCHAR(255), zero_balance_code VARCHAR(255), zero_balance_effective_date VARCHAR(255), last_paid_installment_date VARCHAR(255), foreclosed_after VARCHAR(255), disposition_date VARCHAR(255), foreclosure_costs VARCHAR(255), prop_preservation_and_reair_costs VARCHAR(255), asset_recovery_costs VARCHAR(255), misc_holding_expenses VARCHAR(255), holding_taxes VARCHAR(255), net_sale_proceeds VARCHAR(255), credit_enhancement_proceeds VARCHAR(255), repurchase_make_whole_proceeds VARCHAR(255), other_foreclosure_proceeds VARCHAR(255), non_interest_bearing_upb VARCHAR(255), principal_forgiveness_upb VARCHAR(255), repurchase_make_whole_proceeds_flag VARCHAR(255), foreclosure_principal_write_off_amount VARCHAR(255), servicing_activity_indicator VARCHAR(255));
#
# postgres tables created
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# starting table load
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2000Q1.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2000Q2.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2000Q3.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2000Q4.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2001Q2.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2001Q3.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2001Q1.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/acq/Acquisition_2001Q4.txt
# Years: 2 Table load time: 15.531671047210693
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# Attempting: UPDATE acq SET borrower_credit_score = cast(nullif(borrower_credit_score, '') AS INTEGER);
# Years: 2 fix_empty_int execution time: 24.896309852600098 field: borrower_credit_score
# acq	id	integer
# acq	loan_id	character varying
# acq	orig_channel	character varying
# acq	seller_name	character varying
# acq	orig_interest_rate	character varying
# acq	orig_upb	character varying
# acq	orig_loan_term	character varying
# acq	orig_date	character varying
# acq	first_pay_date	character varying
# acq	orig_ltv	character varying
# acq	orig_cltv	character varying
# acq	num_borrowers	character varying
# acq	dti	character varying
# acq	borrower_credit_score	integer
# acq	first_home_buyer	character varying
# acq	loan_purpose	character varying
# acq	property_type	character varying
# acq	num_units	character varying
# acq	occupancy_status	character varying
# acq	property_state	character varying
# acq	zip	character varying
# acq	mortgage_insurance_percent	character varying
# acq	product_type	character varying
# acq	coborrow_credit_score	character varying
# acq	mortgage_insurance_type	character varying
# acq	relocation_mortgage_indicator	character varying
# acq	dummy	character varying
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# starting table load
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q4.txt_0
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2000Q1.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q4.txt_1
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2000Q2.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2000Q3.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q2.txt_0
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q2.txt_1
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2000Q4.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q1.txt
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q3.txt_1
# /Users/robertdill/github/mortgage-analysis-example/data/text/perf/Performance_2001Q3.txt_0
# Years: 2 Table load time: 481.6778869628906
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# Attempting: UPDATE perf SET current_loan_delinquency_status = cast(nullif(current_loan_delinquency_status, '') AS INTEGER);
# Years: 2 fix_empty_int execution time: 1672.6802611351013 field: current_loan_delinquency_status
# Attempting: UPDATE perf SET current_actual_upb = cast(nullif(current_actual_upb, '') AS DECIMAL);
# Years: 2 fix_empty_int execution time: 1770.4314918518066 field: current_actual_upb
# Attempting: UPDATE perf SET loan_age = cast(nullif(loan_age, '') AS DECIMAL);
# Years: 2 fix_empty_int execution time: 1737.8749539852142 field: loan_age
# perf	id	integer
# perf	loan_id	character varying
# perf	monthly_reporting_period	character varying
# perf	servicer	character varying
# perf	interest_rate	character varying
# perf	current_actual_upb	numeric
# perf	loan_age	numeric
# perf	remaining_months_to_legal_maturity	character varying
# perf	adj_remaining_months_to_maturity	character varying
# perf	maturity_date	character varying
# perf	msa	character varying
# perf	current_loan_delinquency_status	integer
# perf	mod_flag	character varying
# perf	zero_balance_code	character varying
# perf	zero_balance_effective_date	character varying
# perf	last_paid_installment_date	character varying
# perf	foreclosed_after	character varying
# perf	disposition_date	character varying
# perf	foreclosure_costs	character varying
# perf	prop_preservation_and_reair_costs	character varying
# perf	asset_recovery_costs	character varying
# perf	misc_holding_expenses	character varying
# perf	holding_taxes	character varying
# perf	net_sale_proceeds	character varying
# perf	credit_enhancement_proceeds	character varying
# perf	repurchase_make_whole_proceeds	character varying
# perf	other_foreclosure_proceeds	character varying
# perf	non_interest_bearing_upb	character varying
# perf	principal_forgiveness_upb	character varying
# perf	repurchase_make_whole_proceeds_flag	character varying
# perf	foreclosure_principal_write_off_amount	character varying
# perf	servicing_activity_indicator	character varying
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# starting countRows sql run
# [(4223742,)]
# Years: 2 count sql execution time: 0.1312391757965088 rows: 4223742
# {'dbname=postgres user=robertdill'}
# Connected to postgres database
# starting countRows sql run
# [(148484702,)]
# Years: 2 count sql execution time: 45.14868092536926 rows: 148484702
# {'dbname=postgres user=robertdill'}
# conn: <connection object at 0x137033760; dsn: 'dbname=postgres user=robertdill', closed: 0>
# Connected to postgres database
# starting summary sql run
# Years: 2 rows: 645 summary sql execution time: 58.22779393196106
# [('/1999', Decimal('1.0'), 157956, Decimal('714.7850137881914641'), Decimal('18665000.0'), Decimal('18665000.0')), ('/1999', Decimal('2.0'), 157956, Decimal('714.7677434332714248'), Decimal('38845000.0'), Decimal('38845000.0')), ('/1999', Decimal('3.0'), 157956, Decimal('714.7608787764924090'), Decimal('47902000.0'), Decimal('47902000.0')), ('/1999', Decimal('4.0'), 157956, Decimal('714.7658551506690301'), Decimal('55827000.0'), Decimal('55827000.0')), ('/1999', Decimal('5.0'), 157956, Decimal('714.7997543661797761'), Decimal('83033965.38'), Decimal('83033965.38')), ('/1999', Decimal('6.0'), 157956, Decimal('714.8830095491486808'), Decimal('6928137827.60'), Decimal('6928137827.60')), ('/1999', Decimal('7.0'), 157956, Decimal('714.8987929856524710'), Decimal('13250332466.30'), Decimal('13250332466.30')), ('/1999', Decimal('8.0'), 157956, Decimal('714.9591642924976258'), Decimal('14490234199.26'), Decimal('14490234199.26')), ('/1999', Decimal('9.0'), 157956, Decimal('715.0052838673412029'), Decimal('14946534257.27'), Decimal('14946534257.27')), ('/1999', Decimal('10.0'), 157956, Decimal('715.0628635864654355'), Decimal('15157520723.60'), Decimal('15157520723.60')), ('/1999', Decimal('11.0'), 157956, Decimal('715.1546872092590525'), Decimal('15324883516.03'), Decimal('15324883516.03')), ('/1999', Decimal('12.0'), 157956, Decimal('715.2221413180771231'), Decimal('15413675231.43'), Decimal('15413675231.43')), ('/1999', Decimal('13.0'), 157956, Decimal('715.3038248109940039'), Decimal('15380223085.59'), Decimal('15380223085.59')), ('/1999', Decimal('14.0'), 157956, Decimal('715.3678803592229362'), Decimal('15230058401.87'), Decimal('15230058401.87')), ('/1999', Decimal('15.0'), 157956, Decimal('715.3767137412451213'), Decimal('14941952530.22'), Decimal('14941952530.22')), ('/1999', Decimal('16.0'), 157956, Decimal('715.4189759317495407'), Decimal('14557358592.88'), Decimal('14557358592.88')), ('/1999', Decimal('17.0'), 157956, Decimal('715.5722273260050052'), Decimal('14178142621.33'), Decimal('14178142621.33')), ('/1999', Decimal('18.0'), 157956, Decimal('715.7211086563566981'), Decimal('13830480076.04'), Decimal('13830480076.04')), ('/1999', Decimal('19.0'), 157956, Decimal('715.8763363637847455'), Decimal('13505376135.02'), Decimal('13505376135.02')), ('/1999', Decimal('20.0'), 157956, Decimal('716.0740274476349812'), Decimal('13186073431.62'), Decimal('13186073431.62')), ('/1999', Decimal('21.0'), 157956, Decimal('716.2066022057712645'), Decimal('12879527376.17'), Decimal('12879527376.17')), ('/1999', Decimal('22.0'), 157956, Decimal('716.1804321625344353'), Decimal('12418757417.12'), Decimal('12418757417.12')), ('/1999', Decimal('23.0'), 157956, Decimal('716.0005179681360291'), Decimal('11862609044.52'), Decimal('11862609044.52')), ('/1999', Decimal('24.0'), 157956, Decimal('715.7557046854233354'), Decimal('11223679016.90'), Decimal('11223679016.90')), ('/1999', Decimal('25.0'), 157956, Decimal('715.5730224211747954'), Decimal('10699255153.98'), Decimal('10699255153.98')), ('/1999', Decimal('26.0'), 157956, Decimal('715.5503348924606261'), Decimal('10286626747.20'), Decimal('10286626747.20')), ('/1999', Decimal('27.0'), 157956, Decimal('715.5067245390899701'), Decimal('9947845949.57'), Decimal('9947845949.57')), ('/1999', Decimal('28.0'), 157956, Decimal('715.5143010810520088'), Decimal('9646466254.11'), Decimal('9646466254.11')), ('/1999', Decimal('29.0'), 157956, Decimal('715.5548081603752711'), Decimal('9377942652.08'), Decimal('9377942652.08')), ('/1999', Decimal('30.0'), 157956, Decimal('715.5857741060587147'), Decimal('9128900388.22'), Decimal('9128900388.22')), ('/1999', Decimal('31.0'), 157956, Decimal('715.6044604097679698'), Decimal('8816806282.80'), Decimal('8816806282.80')), ('/1999', Decimal('32.0'), 157956, Decimal('715.4421558864249107'), Decimal('8441970350.16'), Decimal('8441970350.16')), ('/1999', Decimal('33.0'), 157956, Decimal('715.0872238843974792'), Decimal('7994572274.01'), Decimal('7994572274.01')), ('/ ...

# %%
# Out:
# {'dbname=postgres user=robertdill'}
# conn: <connection object at 0x137033df0; dsn: 'dbname=postgres user=robertdill', closed: 0>
# Connected to postgres database
# starting summary sql run
# Years: 2 rows: 645 summary sql execution time: 51.65659499168396
# [('/1999', Decimal('1.0'), 157956, Decimal('714.7850137881914641'), Decimal('18665000.0'), Decimal('18665000.0')), ('/1999', Decimal('2.0'), 157956, Decimal('714.7677434332714248'), Decimal('38845000.0'), Decimal('38845000.0')), ('/1999', Decimal('3.0'), 157956, Decimal('714.7608787764924090'), Decimal('47902000.0'), Decimal('47902000.0')), ('/1999', Decimal('4.0'), 157956, Decimal('714.7658551506690301'), Decimal('55827000.0'), Decimal('55827000.0')), ('/1999', Decimal('5.0'), 157956, Decimal('714.7997543661797761'), Decimal('83033965.38'), Decimal('83033965.38')), ('/1999', Decimal('6.0'), 157956, Decimal('714.8830095491486808'), Decimal('6928137827.60'), Decimal('6928137827.60')), ('/1999', Decimal('7.0'), 157956, Decimal('714.8987929856524710'), Decimal('13250332466.30'), Decimal('13250332466.30')), ('/1999', Decimal('8.0'), 157956, Decimal('714.9591642924976258'), Decimal('14490234199.26'), Decimal('14490234199.26')), ('/1999', Decimal('9.0'), 157956, Decimal('715.0052838673412029'), Decimal('14946534257.27'), Decimal('14946534257.27')), ('/1999', Decimal('10.0'), 157956, Decimal('715.0628635864654355'), Decimal('15157520723.60'), Decimal('15157520723.60')), ('/1999', Decimal('11.0'), 157956, Decimal('715.1546872092590525'), Decimal('15324883516.03'), Decimal('15324883516.03')), ('/1999', Decimal('12.0'), 157956, Decimal('715.2221413180771231'), Decimal('15413675231.43'), Decimal('15413675231.43')), ('/1999', Decimal('13.0'), 157956, Decimal('715.3038248109940039'), Decimal('15380223085.59'), Decimal('15380223085.59')), ('/1999', Decimal('14.0'), 157956, Decimal('715.3678803592229362'), Decimal('15230058401.87'), Decimal('15230058401.87')), ('/1999', Decimal('15.0'), 157956, Decimal('715.3767137412451213'), Decimal('14941952530.22'), Decimal('14941952530.22')), ('/1999', Decimal('16.0'), 157956, Decimal('715.4189759317495407'), Decimal('14557358592.88'), Decimal('14557358592.88')), ('/1999', Decimal('17.0'), 157956, Decimal('715.5722273260050052'), Decimal('14178142621.33'), Decimal('14178142621.33')), ('/1999', Decimal('18.0'), 157956, Decimal('715.7211086563566981'), Decimal('13830480076.04'), Decimal('13830480076.04')), ('/1999', Decimal('19.0'), 157956, Decimal('715.8763363637847455'), Decimal('13505376135.02'), Decimal('13505376135.02')), ('/1999', Decimal('20.0'), 157956, Decimal('716.0740274476349812'), Decimal('13186073431.62'), Decimal('13186073431.62')), ('/1999', Decimal('21.0'), 157956, Decimal('716.2066022057712645'), Decimal('12879527376.17'), Decimal('12879527376.17')), ('/1999', Decimal('22.0'), 157956, Decimal('716.1804321625344353'), Decimal('12418757417.12'), Decimal('12418757417.12')), ('/1999', Decimal('23.0'), 157956, Decimal('716.0005179681360291'), Decimal('11862609044.52'), Decimal('11862609044.52')), ('/1999', Decimal('24.0'), 157956, Decimal('715.7557046854233354'), Decimal('11223679016.90'), Decimal('11223679016.90')), ('/1999', Decimal('25.0'), 157956, Decimal('715.5730224211747954'), Decimal('10699255153.98'), Decimal('10699255153.98')), ('/1999', Decimal('26.0'), 157956, Decimal('715.5503348924606261'), Decimal('10286626747.20'), Decimal('10286626747.20')), ('/1999', Decimal('27.0'), 157956, Decimal('715.5067245390899701'), Decimal('9947845949.57'), Decimal('9947845949.57')), ('/1999', Decimal('28.0'), 157956, Decimal('715.5143010810520088'), Decimal('9646466254.11'), Decimal('9646466254.11')), ('/1999', Decimal('29.0'), 157956, Decimal('715.5548081603752711'), Decimal('9377942652.08'), Decimal('9377942652.08')), ('/1999', Decimal('30.0'), 157956, Decimal('715.5857741060587147'), Decimal('9128900388.22'), Decimal('9128900388.22')), ('/1999', Decimal('31.0'), 157956, Decimal('715.6044604097679698'), Decimal('8816806282.80'), Decimal('8816806282.80')), ('/1999', Decimal('32.0'), 157956, Decimal('715.4421558864249107'), Decimal('8441970350.16'), Decimal('8441970350.16')), ('/1999', Decimal('33.0'), 157956, Decimal('715.0872238843974792'), Decimal('7994572274.01'), Decimal('7994572274.01')), ('/ ...
