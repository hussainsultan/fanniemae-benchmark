# %% [markdown]
# # Objective
# Run test cases for different thread counts and different db sizes
# Initial run 'assumes' that the 16-year data set has already been downloaded and built as parquet files.

# %%
# import required services
import datetime
import json
import platform
import time
import warnings
from pathlib import Path
import os
import glob
import shutil

import click
import duckdb
import ibis
import psutil
from jinja2 import Template
from memory_profiler import memory_usage

# %%
def setThreadsAndYears(threads, years):
    global env
    env = {}
    # specify benchmark characteristics
    # number of processors to use for this run
    env["thread_count"] = threads
    # number of years to use for this run
    env["year_count"] = years
    # execution mode
    env["mode"] = "sql"

    # set up the select criteria for finding the correct performance and acquisition files
    if years > 10:
        #first 10 years
        year_list = list(range(0,10))
        env["perf_regex"] = "'Performance_200{0}*.parquet'".format(year_list)
        env["acq_regex"] = "'Acquisition_200{0}*.parquet'".format(year_list)
        #everything else
        year_list = list(range(0,env["year_count"]-10))
        env["perf_regex_2"] = "'Performance_201{0}*.parquet'".format(year_list)
        env["acq_regex_2"] = "'Acquisition_201{0}*.parquet'".format(year_list)
    else:
        env["acq_regex_2"] = None
        env["perf_regex_2"] = None
        year_list = list(range(0,env["year_count"]))
        env["perf_regex"] = "'Performance_200{0}*.parquet'".format(year_list)
        env["acq_regex"] = "'Acquisition_200{0}*.parquet'".format(year_list)

# %%
def setGlobals():
    global env
    # specify the name of the 'data' sub-folder
    env["data_folder"] = "data"
    #enable this to run on Linux, OSX, Windows
    env["path_separator"] = os.path.sep
    performance_folder = "perf"
    acquisition_folder = "acq"
    # define path information for source data sets. 
    env["base_path"] = os.getcwd()
    env["data_path"] = env["base_path"] + env["path_separator"] + env["data_folder"]
    env["perf_path"] = env["data_path"] + env["path_separator"] + performance_folder
    env["acq_path"] = env["data_path"] + env["path_separator"] + acquisition_folder

    env["perf_temp"] = "perf1"
    env["acq_temp"] = "acq1"
    env["perf_temp_path"] = env["data_path"] + env["path_separator"] + env["perf_temp"]
    env["acq_temp_path"] = env["data_path"] + env["path_separator"] + env["acq_temp"]

    os.chdir(env["data_path"])
    # create temp folders if needed for this run
    ![ -d "{env['perf_temp']}" ] || mkdir "{env['perf_temp']}"
    ![ -d "{env['acq_temp']}" ] || mkdir "{env['acq_temp']}"
    # if the temp folders have content, empty them
    os.chdir(env["perf_temp_path"])
    #print(os.getcwd())
    #!ls
    #print("removing files ")
    # !rm *.*
    #print("ls after removal\n")
    #!ls
    os.chdir(env["acq_temp_path"])
    #print(os.getcwd())
    # !rm *.*
    #!ls

# %%
def copyMortgageFiles():
    global env
    # get a list of the files to be copied
    os.chdir(env["perf_path"])
    perf_list = eval("glob.glob({0})".format(env["perf_regex"]))
    if env["perf_regex_2"] != None:
        t_list = eval("glob.glob({0})".format(env["perf_regex_2"]))
        perf_list = perf_list + t_list
    os.chdir(env["acq_path"])
    t_str = "glob.glob({0})".format(env["acq_regex"])
    acq_list = eval(t_str)
    if env["acq_regex_2"] != None:
        t_list = eval("glob.glob({0})".format(env["acq_regex_2"]))
        acq_list = acq_list + t_list
    # reset back to the root folder for this repo. 
    os.chdir(env["base_path"])
    
    # copy over just those parquet files to be used for this run
    # performance folder copy
    src_base = env["perf_path"] + env["path_separator"]
    target_base = env["data_path"] + env["path_separator"] + env["perf_temp"] + env["path_separator"]
    for each in perf_list:
        shutil.copyfile(src_base + each, target_base + each)

    # acquisition folder copy
    src_base = env["acq_path"] + env["path_separator"]
    target_base = env["data_path"] + env["path_separator"] + env["acq_temp"] + env["path_separator"]

    for each in acq_list:
        shutil.copyfile(src_base + each, target_base + each)

# %%
def create_db(datadir):
    global env
    conn = duckdb.connect("mortgage.db")
    perf_path = env["perf_temp_path"] + env["path_separator"] + "*.parquet"
    acq_path =  env["acq_temp_path"] + env["path_separator"] + "*.parquet"
    conn.execute(f"CREATE OR REPLACE VIEW perf AS SELECT * FROM '{perf_path}'")
    conn.execute(f"CREATE OR REPLACE VIEW acq AS SELECT * FROM '{acq_path}'")
    conn.close()

# %%
def summary_expr(datadir):
    db = ibis.duckdb.connect("mortgage.db")
    perf = db.table("perf")
    acq = db.table("acq")
    t0 = time.time()
    acq = acq[
        acq.loan_id, acq.orig_date.split("/")[1].name("year"), acq.borrower_credit_score
    ]
    joined = acq.inner_join(perf, acq.loan_id == perf.loan_id)
    t1 = time.time()
    chargeoffs = (
        ibis.case()
        .when(
            (perf.zero_balance_code.isin(["02", "03", "09", "15"]))
            & (perf.disposition_date.notnull()),
            1,
        )
        .else_(0)
        .end()
        .name("charegoffs")
    )
    t2 = time.time()
    
    dollar_co = (
        perf.zero_balance_code.isin(["02", "03", "09", "15"])
        & (perf.disposition_date.notnull())
    ).ifelse(perf.current_actual_upb, 0)
    t3 = time.time()
    
    loans = joined.mutate(chargeoffs=chargeoffs, dollar_co=dollar_co).projection(
        [
            perf.loan_id,
            chargeoffs,
            dollar_co.name("dollar_co"),
            perf.loan_age,
            perf.current_actual_upb,
            acq.year,
            acq.borrower_credit_score,
        ]
    )
    t4 = time.time()
    
    summary = (
        loans[loans.loan_age > 0]
        .groupby([loans.year, loans.loan_age])
        .aggregate(
            co_count=lambda x: x.charegoffs.cast("int64").sum(),
            dollar_co=lambda x: x.dollar_co.sum(),
            avg_credit_score=lambda x: x.borrower_credit_score.mean(),
            upb_sum=lambda x: x.current_actual_upb.sum(),
        )
    )
    t5 = time.time()
    
    acq_agg = acq.groupby([acq.year]).loan_id.count()
    t6 = time.time()
    
    summary = summary.inner_join(acq_agg, acq_agg.year == summary.year)
    t7 = time.time()
    
    summary = summary.projection(
        [
            summary.year_x,
            summary.loan_age,
            summary["count(loan_id)"],
            summary.avg_credit_score,
            summary.upb_sum,
            summary.dollar_co,
        ]
    )
    t8 = time.time()
    print(f"t1: {t1-t0}\t t2: {t2-t1}\t t3: {t3-t2}\t t4: {t4-t3}\t t5: {t5-t4}\t t6: {t6-t5}\t t7: {t7-t6}")
    del db
    return summary

# %%
def summary_sql(datadir):
    global env
    perf_path = env["perf_temp_path"] + env["path_separator"] + "*.parquet"
    acq_path =  env["acq_temp_path"] + env["path_separator"] + "*.parquet"
    with open("summary.sql") as f:
        template = Template(f.read())
    return template.render(
        perf=str(perf_path), acq=str(acq_path)
    )

# %%
def window_sql(datadir):
    global env
    perf_path = env["perf_temp_path"] + env["path_separator"] + "*.parquet"
    acq_path =  env["acq_temp_path"] + env["path_separator"] + "*.parquet"

    sql = f"select count(*) from (select RANK() OVER (PARTITION BY loan_id ORDER BY monthly_reporting_period) as number from '{perf_path}')"
    return sql

# %%
def execute(expr, threads=8):
    conn = duckdb.connect("mortgage.db")
    conn.execute(f"PRAGMA threads={threads}")
    result = conn.execute(str(expr)).fetchall()
    conn.close()
    return result

# %%
def platform_info():
    return {
        "machine": platform.machine(),
        "version": platform.version(),
        "platform": platform.platform(),
        "system": platform.system(),
        "cpu_count": psutil.cpu_count(),
        "memory": psutil.virtual_memory().total,
        "processor": platform.processor(),
    }

# %%
def main(mode, datadir, threads):
    global thread_count
    datadir = Path(datadir)
    # t3 = time.time()
    create_db(datadir)
    # t4 = time.time()
    # print(f"time to create database: {t4-t3}")
    
    if mode == "ibis":
        summary = summary_expr(datadir)
        sql = summary.compile().compile(compile_kwargs={"literal_binds": True})
    else:
        sql = summary_sql(datadir)
    #t5 = time.time()
    row_count_perf = execute("select count(*) from perf")[0][0]
    row_count_acq = execute("select count(*) from acq")[0][0]
    #t6 = time.time()
    #print(f"time to count rows: {t6-t5}")
    #if threads:
        #runs = range(2, psutil.cpu_count() + 2, 2)
    #else:
        #runs = [psutil.cpu_count()]
    runs = [env["thread_count"]]
    result = []
    for thread in runs:
        start_time = time.time()
        mem = memory_usage(
            (
                execute,
                (
                    sql,
                    thread,
                ),
            )
        )
        total_time = time.time() - start_time

        data = {
            **platform_info(),
            "threads": thread,
            "run_date": datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"),
            "total_time": total_time,
            "row_count_perf": row_count_perf,
            "row_count_acq": row_count_acq,
            "max_memory_usage": max(mem),
            "incremental_memory_usage": mem[-1] - mem[0],
            "sql": " ".join(str(sql).split()),
        }
        result.append(data)
    # print(json.dumps(result))

    return(result)

# %%
def threadCompare():
    t1 = []
    _cpus = (platform_info())["cpu_count"]
    for y in range (2, 17, 2):

        for t in range(1, _cpus+1):
            setThreadsAndYears(t,y)
            setGlobals()
            copyMortgageFiles()

            res  = main(env["mode"], env["data_folder"], env["thread_count"])

            print(f"CPUs: {res[0]['cpu_count']} Threads: {res[0]['threads']} \t Years: {env['year_count']} \t Elapsed Time: {res[0]['total_time']} ")
            res[0]['year_count'] = env['year_count']
            t1.append(res[0])
    return t1

# %%
def getVariance():
    # change the _threads tuple to represent the range of threads to use for this run
    # change the _years tuple to represent the year sets to execute against. 
    # year range can be from 1 to 17.
    # set iterations to be the number of times each query is run. Default is 10.
    # iterations is used to determin average and standard deviation
    _threads = range(2,8)
    _years = range(2,13,2)
    _iterations = 10
    _res = []
    _iter = 0
    for y in _years:
        for t in _threads:
            for i in range(0,_iterations):
                setThreadsAndYears(t,y)
                setGlobals()
                copyMortgageFiles()
                res  = main(env["mode"], env["data_folder"], env["thread_count"])
                _res.append({"iteration": i, "threads": res[0]['cpu_count'], "years": env['year_count'], "e_time": res[0]['total_time']})
                _iter +=1
                print(f"[{i}]\tCPUs: {res[0]['cpu_count']} Threads: {res[0]['threads']} \t Years: {env['year_count']} \t Elapsed Time: {res[0]['total_time']} ")
                res[0]['year_count'] = env['year_count']
    return _res

# %%
variance = getVariance()
print(variance)
# Out:
# [0]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.403039932250977
# [1]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.317246913909912
# [2]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.340960025787354
# [3]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.69429302215576
# [4]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.389846086502075
# [5]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.271837949752808
# [6]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.716387033462524
# [7]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.311625003814697
# [8]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.330898761749268
# [9]	CPUs: 10 Threads: 2 	 Years: 2 	 Elapsed Time: 27.33625817298889
# [0]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.47749900817871
# [1]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.410190105438232
# [2]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.31891918182373
# [3]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.303781032562256
# [4]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.346294164657593
# [5]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.487030029296875
# [6]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.323291301727295
# [7]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.182252883911133
# [8]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.340045928955078
# [9]	CPUs: 10 Threads: 3 	 Years: 2 	 Elapsed Time: 20.385932683944702
# [0]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.950653791427612
# [1]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 16.10095500946045
# [2]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.972457885742188
# [3]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.78873896598816
# [4]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.915462017059326
# [5]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.95795488357544
# [6]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.940567016601562
# [7]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 15.942387104034424
# [8]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 16.122918844223022
# [9]	CPUs: 10 Threads: 4 	 Years: 2 	 Elapsed Time: 16.036792993545532
# [0]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.465453863143921
# [1]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.792415857315063
# [2]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.454712152481079
# [3]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.526501893997192
# [4]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.561226844787598
# [5]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.448493957519531
# [6]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.484510898590088
# [7]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.58020305633545
# [8]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.46854305267334
# [9]	CPUs: 10 Threads: 5 	 Years: 2 	 Elapsed Time: 12.587282180786133
# [0]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 11.952551126480103
# [1]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 12.045642852783203
# [2]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 12.038203954696655
# [3]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 11.978185892105103
# [4]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 12.123893022537231
# [5]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 12.00088906288147
# [6]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 11.993691205978394
# [7]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 12.043568134307861
# [8]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 12.02849817276001
# [9]	CPUs: 10 Threads: 6 	 Years: 2 	 Elapsed Time: 11.938647031784058
# [0]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.414397954940796
# [1]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.45814299583435
# [2]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.669597864151001
# [3]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.839287996292114
# [4]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.53631591796875
# [5]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.630489110946655
# [6]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.489743947982788
# [7]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.46355676651001
# [8]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.56137228012085
# [9]	CPUs: 10 Threads: 7 	 Years: 2 	 Elapsed Time: 10.622803926467896
# [0]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 192.09296321868896
# [1]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 197.99889206886292
# [2]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 198.14332270622253
# [3]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 196.42122983932495
# [4]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 193.7400450706482
# [5]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 191.90870809555054
# [6]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 195.00578927993774
# [7]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 195.98430013656616
# [8]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 195.47321701049805
# [9]	CPUs: 10 Threads: 2 	 Years: 4 	 Elapsed Time: 189.84118700027466
# [0]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 138.4867560863495
# [1]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 138.3076310157776
# [2]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 138.51977705955505
# [3]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 143.47643899917603
# [4]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 137.5267698764801
# [5]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 138.05721712112427
# [6]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 138.59313106536865
# [7]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 138.2846291065216
# [8]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 150.60650396347046
# [9]	CPUs: 10 Threads: 3 	 Years: 4 	 Elapsed Time: 140.71384596824646
# [0]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 99.87467694282532
# [1]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 97.8018102645874
# [2]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 99.82924604415894
# [3]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 97.80781102180481
# [4]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 98.42979216575623
# [5]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 100.15093898773193
# [6]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 97.71126508712769
# [7]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 99.72823119163513
# [8]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 95.99853301048279
# [9]	CPUs: 10 Threads: 4 	 Years: 4 	 Elapsed Time: 98.82179713249207
# [0]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 84.34788298606873
# [1]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 80.42310380935669
# [2]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 82.9790871143341
# [3]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 86.33587884902954
# [4]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 83.37737798690796
# [5]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 80.06725215911865
# [6]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 81.40977692604065
# [7]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 82.68423676490784
# [8]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 84.41860103607178
# [9]	CPUs: 10 Threads: 5 	 Years: 4 	 Elapsed Time: 81.60343885421753
# [0]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 64.80405807495117
# [1]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 73.54823088645935
# [2]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 73.67135620117188
# [3]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 66.79332709312439
# [4]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 73.30690717697144
# [5]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 66.2361307144165
# [6]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 68.24381995201111
# [7]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 66.6879448890686
# [8]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 67.71987104415894
# [9]	CPUs: 10 Threads: 6 	 Years: 4 	 Elapsed Time: 72.55636310577393
# [0]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 63.50335502624512
# [1]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 62.235092878341675
# [2]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 58.846933126449585
# [3]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 62.38604807853699
# [4]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 62.29734182357788
# [5]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 57.05154013633728
# [6]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 62.16424489021301
# [7]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 60.87949323654175
# [8]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 59.36189794540405
# [9]	CPUs: 10 Threads: 7 	 Years: 4 	 Elapsed Time: 62.415711879730225
# [0]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 353.6520640850067
# [1]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 359.8724262714386
# [2]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 355.2411217689514
# [3]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 355.77891516685486
# [4]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 358.36515831947327
# [5]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 352.702036857605
# [6]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 353.7067279815674
# [7]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 355.32215118408203
# [8]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 355.1069538593292
# [9]	CPUs: 10 Threads: 2 	 Years: 6 	 Elapsed Time: 348.7478790283203
# [0]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 227.20169115066528
# [1]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 223.50176620483398
# [2]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 223.5991129875183
# [3]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 223.40745186805725
# [4]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 222.454931974411
# [5]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 223.418603181839
# [6]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 227.38641095161438
# [7]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 236.4138081073761
# [8]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 218.69079279899597
# [9]	CPUs: 10 Threads: 3 	 Years: 6 	 Elapsed Time: 230.99090266227722
# [0]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 171.4523160457611
# [1]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 172.37799191474915
# [2]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 165.52133107185364
# [3]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 167.8539218902588
# [4]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 174.79737210273743
# [5]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 170.53618931770325
# [6]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 169.86293196678162
# [7]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 170.00260305404663
# [8]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 165.8413860797882
# [9]	CPUs: 10 Threads: 4 	 Years: 6 	 Elapsed Time: 167.78621077537537
# [0]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 136.85176610946655
# [1]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 124.30515503883362
# [2]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 133.12066888809204
# [3]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 132.91408801078796
# [4]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 130.3863308429718
# [5]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 132.4996280670166
# [6]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 132.63051891326904
# [7]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 128.46951508522034
# [8]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 122.94953489303589
# [9]	CPUs: 10 Threads: 5 	 Years: 6 	 Elapsed Time: 128.28202319145203
# [0]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 109.72803807258606
# [1]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 111.60780000686646
# [2]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 113.11268901824951
# [3]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 107.83406782150269
# [4]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 110.51083421707153
# [5]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 104.89300727844238
# [6]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 106.41153311729431
# [7]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 112.86114025115967
# [8]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 106.33140182495117
# [9]	CPUs: 10 Threads: 6 	 Years: 6 	 Elapsed Time: 108.28104281425476
# [0]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 97.88091373443604
# [1]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 87.27048707008362
# [2]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 84.61524796485901
# [3]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 84.42930102348328
# [4]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 91.46711874008179
# [5]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 93.6605019569397
# [6]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 90.52783298492432
# [7]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 84.48055505752563
# [8]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 85.00350308418274
# [9]	CPUs: 10 Threads: 7 	 Years: 6 	 Elapsed Time: 84.939777135849
# [0]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 461.0250675678253
# [1]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 461.8267869949341
# [2]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 463.13126277923584
# [3]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 462.71965169906616
# [4]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 460.98174691200256
# [5]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 461.6937029361725
# [6]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 462.47710490226746
# [7]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 462.8339171409607
# [8]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 461.1576659679413
# [9]	CPUs: 10 Threads: 2 	 Years: 8 	 Elapsed Time: 461.03733015060425
# [0]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 278.4620759487152
# [1]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 319.7620131969452
# [2]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 291.43227910995483
# [3]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 280.12639904022217
# [4]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 317.7587411403656
# [5]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 281.2587568759918
# [6]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 292.5976278781891
# [7]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 281.3530697822571
# [8]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 316.29048895835876
# [9]	CPUs: 10 Threads: 3 	 Years: 8 	 Elapsed Time: 287.89959597587585
# [0]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 232.0499918460846
# [1]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 243.83577179908752
# [2]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 228.74112010002136
# [3]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 231.9871060848236
# [4]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 246.64491295814514
# [5]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 232.12214708328247
# [6]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 231.671462059021
# [7]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 233.61630988121033
# [8]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 229.05477595329285
# [9]	CPUs: 10 Threads: 4 	 Years: 8 	 Elapsed Time: 243.38696813583374
# [0]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 177.47892093658447
# [1]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 177.43059706687927
# [2]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 163.7100419998169
# [3]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 177.86518597602844
# [4]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 182.0679807662964
# [5]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 178.29055881500244
# [6]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 179.78553009033203
# [7]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 177.58095502853394
# [8]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 183.65353393554688
# [9]	CPUs: 10 Threads: 5 	 Years: 8 	 Elapsed Time: 179.9193229675293
# [0]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 141.8372302055359
# [1]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 161.7949230670929
# [2]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 145.09581518173218
# [3]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 152.22618103027344
# [4]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 148.1081621646881
# [5]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 155.88110899925232
# [6]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 155.31333684921265
# [7]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 144.99399495124817
# [8]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 148.80707597732544
# [9]	CPUs: 10 Threads: 6 	 Years: 8 	 Elapsed Time: 158.8818781375885
# [0]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 109.46958804130554
# [1]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 108.3164598941803
# [2]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 111.89415502548218
# [3]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 103.2864511013031
# [4]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 103.67530488967896
# [5]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 103.91384506225586
# [6]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 103.40405511856079
# [7]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 103.35254907608032
# [8]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 104.37839674949646
# [9]	CPUs: 10 Threads: 7 	 Years: 8 	 Elapsed Time: 103.43624377250671
# [0]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 471.8189423084259
# [1]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 494.7264037132263
# [2]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 478.18601298332214
# [3]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 523.0112688541412
# [4]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 500.30833196640015
# [5]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 501.45666098594666
# [6]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 494.3483018875122
# [7]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 478.3670451641083
# [8]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 534.8732857704163
# [9]	CPUs: 10 Threads: 2 	 Years: 10 	 Elapsed Time: 515.396861076355
# [0]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 309.6652798652649
# [1]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 335.3974521160126
# [2]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 309.6428921222687
# [3]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 309.849702835083
# [4]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 328.57529282569885
# [5]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 351.59168696403503
# [6]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 309.7760241031647
# [7]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 333.2136158943176
# [8]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 324.85518527030945
# [9]	CPUs: 10 Threads: 3 	 Years: 10 	 Elapsed Time: 329.0889050960541
# [0]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 262.6522800922394
# [1]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 276.52809405326843
# [2]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 256.0614240169525
# [3]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 254.82462096214294
# [4]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 272.3032908439636
# [5]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 268.99574518203735
# [6]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 255.55335927009583
# [7]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 259.0974597930908
# [8]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 258.1227111816406
# [9]	CPUs: 10 Threads: 4 	 Years: 10 	 Elapsed Time: 269.7979049682617
# [0]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 173.57978701591492
# [1]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 187.5469868183136
# [2]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 180.89205193519592
# [3]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 186.80910801887512
# [4]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 192.45624017715454
# [5]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 171.90855503082275
# [6]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 187.656409740448
# [7]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 185.1233150959015
# [8]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 187.7485499382019
# [9]	CPUs: 10 Threads: 5 	 Years: 10 	 Elapsed Time: 194.80453181266785
# [0]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 129.77456712722778
# [1]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 134.78133296966553
# [2]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 132.20440196990967
# [3]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 139.38974380493164
# [4]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 134.2451629638672
# [5]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 134.51371026039124
# [6]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 139.24985790252686
# [7]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 129.14815068244934
# [8]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 132.9905879497528
# [9]	CPUs: 10 Threads: 6 	 Years: 10 	 Elapsed Time: 129.13924193382263
# [0]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 108.46578407287598
# [1]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 108.58665990829468
# [2]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 108.83153104782104
# [3]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 108.0997519493103
# [4]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 108.8675000667572
# [5]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 108.38197207450867
# [6]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 106.10323572158813
# [7]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 105.90240001678467
# [8]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 107.71591711044312
# [9]	CPUs: 10 Threads: 7 	 Years: 10 	 Elapsed Time: 103.46623706817627
# [0]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 640.8454170227051
# [1]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 609.4715132713318
# [2]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 637.6611068248749
# [3]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 612.6057741641998
# [4]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 597.4058511257172
# [5]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 590.9311981201172
# [6]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 617.6254279613495
# [7]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 626.4635400772095
# [8]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 590.8598568439484
# [9]	CPUs: 10 Threads: 2 	 Years: 12 	 Elapsed Time: 611.9822819232941
# [0]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 413.7939019203186
# [1]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 414.4150130748749
# [2]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 409.2961959838867
# [3]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 412.3892111778259
# [4]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 412.7234160900116
# [5]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 408.14138412475586
# [6]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 417.83912920951843
# [7]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 408.6646656990051
# [8]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 399.04453897476196
# [9]	CPUs: 10 Threads: 3 	 Years: 12 	 Elapsed Time: 415.25677013397217
# [0]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 316.4909830093384
# [1]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 302.22039771080017
# [2]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 315.1563458442688
# [3]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 296.7247750759125
# [4]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 280.8853349685669
# [5]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 308.7488398551941
# [6]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 272.61387395858765
# [7]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 309.8252742290497
# [8]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 282.4360032081604
# [9]	CPUs: 10 Threads: 4 	 Years: 12 	 Elapsed Time: 296.8037917613983
# [0]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 229.56878471374512
# [1]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 230.53376507759094
# [2]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 222.76025295257568
# [3]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 215.45650029182434
# [4]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 222.97865295410156
# [5]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 224.5858392715454
# [6]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 233.15979313850403
# [7]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 238.97596788406372
# [8]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 229.58287501335144
# [9]	CPUs: 10 Threads: 5 	 Years: 12 	 Elapsed Time: 229.69392085075378
# [0]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 142.95611190795898
# [1]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 146.3533799648285
# [2]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 153.49745106697083
# [3]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 139.7856409549713
# [4]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 142.48803400993347
# [5]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 150.57204413414001
# [6]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 144.1331992149353
# [7]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 143.5051019191742
# [8]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 157.79818391799927
# [9]	CPUs: 10 Threads: 6 	 Years: 12 	 Elapsed Time: 143.3224880695343
# [0]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 114.65583992004395
# [1]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 119.8787887096405
# [2]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 121.36246395111084
# [3]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 116.66554880142212
# [4]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 118.2992799282074
# [5]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 116.31049275398254
# [6]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 115.60625505447388
# [7]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 125.06162095069885
# [8]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 124.991219997406
# [9]	CPUs: 10 Threads: 7 	 Years: 12 	 Elapsed Time: 124.71072101593018
# [{'iteration': 0, 'threads': 10, 'years': 2, 'e_time': 27.403039932250977}, {'iteration': 1, 'threads': 10, 'years': 2, 'e_time': 27.317246913909912}, {'iteration': 2, 'threads': 10, 'years': 2, 'e_time': 27.340960025787354}, {'iteration': 3, 'threads': 10, 'years': 2, 'e_time': 27.69429302215576}, {'iteration': 4, 'threads': 10, 'years': 2, 'e_time': 27.389846086502075}, {'iteration': 5, 'threads': 10, 'years': 2, 'e_time': 27.271837949752808}, {'iteration': 6, 'threads': 10, 'years': 2, 'e_time': 27.716387033462524}, {'iteration': 7, 'threads': 10, 'years': 2, 'e_time': 27.311625003814697}, {'iteration': 8, 'threads': 10, 'years': 2, 'e_time': 27.330898761749268}, {'iteration': 9, 'threads': 10, 'years': 2, 'e_time': 27.33625817298889}, {'iteration': 0, 'threads': 10, 'years': 2, 'e_time': 20.47749900817871}, {'iteration': 1, 'threads': 10, 'years': 2, 'e_time': 20.410190105438232}, {'iteration': 2, 'threads': 10, 'years': 2, 'e_time': 20.31891918182373}, {'iteration': 3, 'threads': 10, 'years': 2, 'e_time': 20.303781032562256}, {'iteration': 4, 'threads': 10, 'years': 2, 'e_time': 20.346294164657593}, {'iteration': 5, 'threads': 10, 'years': 2, 'e_time': 20.487030029296875}, {'iteration': 6, 'threads': 10, 'years': 2, 'e_time': 20.323291301727295}, {'iteration': 7, 'threads': 10, 'years': 2, 'e_time': 20.182252883911133}, {'iteration': 8, 'threads': 10, 'years': 2, 'e_time': 20.340045928955078}, {'iteration': 9, 'threads': 10, 'years': 2, 'e_time': 20.385932683944702}, {'iteration': 0, 'threads': 10, 'years': 2, 'e_time': 15.950653791427612}, {'iteration': 1, 'threads': 10, 'years': 2, 'e_time': 16.10095500946045}, {'iteration': 2, 'threads': 10, 'years': 2, 'e_time': 15.972457885742188}, {'iteration': 3, 'threads': 10, 'years': 2, 'e_time': 15.78873896598816}, {'iteration': 4, 'threads': 10, 'years': 2, 'e_time': 15.915462017059326}, {'iteration': 5, 'threads': 10, 'years': 2, 'e_time': 15.95795488357544}, {'iteration': 6, 'threads': 10, 'years': 2, 'e_time': 15.940567016601562}, {'iteration': 7, 'threads': 10, 'years': 2, 'e_time': 15.942387104034424}, {'iteration': 8, 'threads': 10, 'years': 2, 'e_time': 16.122918844223022}, {'iteration': 9, 'threads': 10, 'years': 2, 'e_time': 16.036792993545532}, {'iteration': 0, 'threads': 10, 'years': 2, 'e_time': 12.465453863143921}, {'iteration': 1, 'threads': 10, 'years': 2, 'e_time': 12.792415857315063}, {'iteration': 2, 'threads': 10, 'years': 2, 'e_time': 12.454712152481079}, {'iteration': 3, 'threads': 10, 'years': 2, 'e_time': 12.526501893997192}, {'iteration': 4, 'threads': 10, 'years': 2, 'e_time': 12.561226844787598}, {'iteration': 5, 'threads': 10, 'years': 2, 'e_time': 12.448493957519531}, {'iteration': 6, 'threads': 10, 'years': 2, 'e_time': 12.484510898590088}, {'iteration': 7, 'threads': 10, 'years': 2, 'e_time': 12.58020305633545}, {'iteration': 8, 'threads': 10, 'years': 2, 'e_time': 12.46854305267334}, {'iteration': 9, 'threads': 10, 'years': 2, 'e_time': 12.587282180786133}, {'iteration': 0, 'threads': 10, 'years': 2, 'e_time': 11.952551126480103}, {'iteration': 1, 'threads': 10, 'years': 2, 'e_time': 12.045642852783203}, {'iteration': 2, 'threads': 10, 'years': 2, 'e_time': 12.038203954696655}, {'iteration': 3, 'threads': 10, 'years': 2, 'e_time': 11.978185892105103}, {'iteration': 4, 'threads': 10, 'years': 2, 'e_time': 12.123893022537231}, {'iteration': 5, 'threads': 10, 'years': 2, 'e_time': 12.00088906288147}, {'iteration': 6, 'threads': 10, 'years': 2, 'e_time': 11.993691205978394}, {'iteration': 7, 'threads': 10, 'years': 2, 'e_time': 12.043568134307861}, {'iteration': 8, 'threads': 10, 'years': 2, 'e_time': 12.02849817276001}, {'iteration': 9, 'threads': 10, 'years': 2, 'e_time': 11.938647031784058}, {'iteration': 0, 'threads': 10, 'years': 2, 'e_time': 10.414397954940796}, {'iteration': 1, 'threads': 10, 'years': 2, 'e_time': 10.45814299583435}, {'iteration': 2, 'threads': 10, 'years': 2, 'e_time': 10.669597864151001}, {'iteration': 3, 'threads': 10, 'yea ...
